# %%
import sys
import xarray as xr
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
from jupyterthemes import jtplot
# currently installed theme will be used to
# set plot style if no arguments provided
jtplot.style()
jtplot.style(theme='chesterish')

# %%
# check the environment
sys.prefix
# Out:
# '/home/igor/anaconda3/envs/MSC_env'

# %%
# setup input variables 
data_folder='/home/igor/UNI/Master_Project/Script/Data/'

# %%
os.listdir(data_folder)
# Out:
# ['.files.txt.swo',
#  'ncr_pdf_douze_05deg.nc',
#  '.files.txt.swp',
#  'cl_l.nc',
#  'ncr_pdf_douze_1deg.nc',
#  'skew_l',
#  'ncr_pdf_douze_0125deg.nc',
#  '125skew.nc',
#  'ncr_pdf_douze_025deg.nc',
#  'files.txt',
#  'ncr_pdf_douze_00625deg.nc',
#  'README_on_douze_files.txt',
#  'range.nc']

# %%
# lets look inside NetCDF input file
# the 00625deg means that the subdomains used for that file were 0.0625 
# of a degree large, so roughly 7x7 km
fname='ncr_pdf_douze_1deg.nc'
filepath=data_folder+fname
# ds contains 63 fields
ds = xr.open_dataset(filepath)

# %%
whos
# Out:
# Variable      Type         Data/Info
# ------------------------------------
# cl_l_data     DataArray    <xarray.DataArray 'cl_l' <...>LES liquid cloud fraction
# data_folder   str          /home/igor/UNI/Master_Project/Script/Data/
# ds            Dataset      <xarray.Dataset>\nDimensi<...>_openmp_thread_number:  1
# filepath      str          /home/igor/UNI/Master_Pro<...>ata/ncr_pdf_douze_1deg.nc
# fname         str          ncr_pdf_douze_1deg.nc
# np            module       <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# os            module       <module 'os' from '/home/<...>env/lib/python3.7/os.py'>
# plt           module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# sys           module       <module 'sys' (built-in)>
# xr            module       <module 'xarray' from '/h<...>ages/xarray/__init__.py'>

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (lev: 150, record: 240, time: 1)
# Coordinates:
#   * time       (time) float64 2.013e+07
# Dimensions without coordinates: lev, record
# Data variables:
#     zm         (record, time, lev) float32 ...
#     qcm        (record, time, lev) float32 ...
#     qim        (record, time, lev) float32 ...
#     qvm        (record, time, lev) float32 ...
#     qtm        (record, time, lev) float32 ...
#     qlm        (record, time, lev) float32 ...
#     qvlm       (record, time, lev) float32 ...
#     qsm        (record, time, lev) float32 ...
#     qsi        (record, time, lev) float32 ...
#     tm         (record, time, lev) float32 ...
#     pm         (record, time, lev) float32 ...
#     cl         (record, time, lev) float32 ...
#     cl_l       (record, time, lev) float32 ...
#     qvu        (record, time, lev) float32 ...
#     tu         (record, time, lev) float32 ...
#     qt_min     (record, time, lev) float32 ...
#     qt_max     (record, time, lev) float32 ...
#     t_min      (record, time, lev) float32 ...
#     t_max      (record, time, lev) float32 ...
#     skew       (record, time, lev) float32 ...
#     var_l      (record, time, lev) float32 ...
#     skew_l     (record, time, lev) float32 ...
#     var        (record, time, lev) float32 ...
#     var_t      (record, time, lev) float32 ...
#     betaq_msl  (record, time, lev) float32 ...
#     betap_msl  (record, time, lev) float32 ...
#     betaa_msl  (record, time, lev) float32 ...
#     betab_msl  (record, time, lev) float32 ...
#     betaq_p00  (record, time, lev) float32 ...
#     betap_p00  (record, time, lev) float32 ...
#     betaa_p00  (record, time, lev) float32 ...
#     betab_p00  (record, time, lev) float32 ...
#     betaq_p06  (record, time, lev) float32 ...
#     betap_p06  (record, time, lev) float32 ...
#     betaa_p06  (record, time, lev) float32 ...
#     betab_p06  (record, time, lev) float32 ...
#     betaa_zsl  (record, time, lev) float32 ...
#     betab_zsl  (record, time, lev) float32 ...
#     betap_zsl  (record, time, lev) float32 ...
#     betaq_zsl  (record, time, lev) float32 ...
#     betaa_1sl  (record, time, lev) float32 ...
#     betab_1sl  (record, time, lev) float32 ...
#     betap_1sl  (record, time, lev) float32 ...
#     betaq_1sl  (record, time, lev) float32 ...
#     sat_zm     (record, time, lev) float32 ...
#     sat_z1     (record, time, lev) float32 ...
#     cl_msl     (record, time, lev) float32 ...
#     cl_p00     (record, time, lev) float32 ...
#     cl_p06     (record, time, lev) float32 ...
#     cl_zsl     (record, time, lev) float32 ...
#     cl_rel     (record, time, lev) float32 ...
#     cl_1sl     (record, time, lev) float32 ...
#     betaa_3sl  (record, time, lev) float32 ...
#     betab_3sl  (record, time, lev) float32 ...
#     betap_3sl  (record, time, lev) float32 ...
#     betaq_3sl  (record, time, lev) float32 ...
#     sat_z3     (record, time, lev) float32 ...
#     cl_3sl     (record, time, lev) float32 ...
#     betaa_p03  (record, time, lev) float32 ...
#     betab_p03  (record, time, lev) float32 ...
#     betap_p03  (record, time, lev) float32 ...
#     betaq_p03  (record, time, lev) float32 ...
#     cl_p03     (record, time, lev) float32 ...
# Attributes:
#     CDI:                       Climate Data Interface version 1.8.1 (http://m...
#     Conventions:               CF-1.6
#     history:                   Sun Jan  3 23:20:16 2021: ncatted -a longname,...
#     CDO:                       Climate Data Operators version 1.8.1 (http://m...
#     NCO:                       netCDF Operators version 4.9.1 (Homepage = htt...
#     nco_openmp_thread_number:  1

# %%
cl_l_data=ds.cl_l[:,0,:]
cl_l_data.shape
# Out:
# (240, 150)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(19,8))
fig.suptitle("ncr_pdf_douze_1deg.nc")

im1=ax1.imshow(ds.pm[:,0,:])
ax1.set_title("pm- Mean pressure",fontsize=18)
ax1.set_ylabel("record=NT*Nslices",fontsize=14)
fig.colorbar(im1, ax=ax1)

im2=ax2.imshow(ds.tm[:,0,:])
ax2.set_title("tm - Mean temperature",fontsize=18)
fig.colorbar(im2, ax=ax2)


for ax in [ax1,ax2]:
    ax.set_xlabel("vertical level",fontsize=14)
plt.savefig("pm_tm_1degree.png")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(19,8))
fig.suptitle("ncr_pdf_douze_1deg.nc")

im1=ax1.imshow(ds.qvlm[:,0,:])
ax1.set_title("qvlm -Mean liquid water + vapor",fontsize=18)
ax1.set_ylabel("record=NT*Nslices",fontsize=14)
fig.colorbar(im1, ax=ax1)

im2=ax2.imshow(ds.qsm[:,0,:])
ax2.set_title("qvm",fontsize=18)
fig.colorbar(im2, ax=ax2)


for ax in [ax1,ax2]:
    ax.set_xlabel("vertical level",fontsize=14)
plt.savefig("qvm_1degree.png")

# %%
ds.qvm[:,0,:].max()
# Out:
# <xarray.DataArray 'qvm' ()>
# array(0.01368841, dtype=float32)
# Coordinates:
#     time     float64 2.013e+07

# %%
ds.qvlm[:,0,:].max()
# Out:
# <xarray.DataArray 'qvlm' ()>
# array(0.01368841, dtype=float32)
# Coordinates:
#     time     float64 2.013e+07

# %%
fig, (ax1, ax2,ax3,ax4) = plt.subplots(1, 4,figsize=(19,8))
fig.suptitle("ncr_pdf_douze_1deg.nc")

ax1.imshow(ds.cl_l[:,0,:])
ax1.set_title("cl_l",fontsize=18)
ax1.set_ylabel("record=NT*Nslices",fontsize=14)
ax2.imshow(ds.cl_msl[:,0,:])
ax2.set_title("cl_msl",fontsize=18)
im3=ax3.imshow(ds.cl_zsl[:,0,:])
ax3.set_title("cl_zsl",fontsize=18)
#fig.colorbar(im3, ax=ax3)

im4=ax4.imshow(ds.cl_rel[:,0,:])
ax4.set_title("cl_rel",fontsize=18)
#fig.colorbar(im4, ax=ax4)
cbar_ax = fig.add_axes([0.91, 0.25, 0.01, 0.5])

fig.colorbar(im4, cax=cbar_ax)
cbar_ax.set_ylabel("liquid cloud fraction")
#fig.subplots_adjust(right=0.8)


for ax in [ax1,ax2,ax3,ax4]:
    ax.set_xlabel("vertical level",fontsize=14)
plt.savefig("cl_l_1degree.png")

# %%
def plot_mean_profile(field):
    fvals=pmvals=ds[field].values
    mean_field_profile=[fvals[:,0,i].mean() for i in range(150)]
    fig=plt.figure(figsize=(12,9))
    plt.plot(mean_field_profile)
    plt.grid()
    plt.title('mean {} profile, averaged over all 61440 entries'.format(field),fontsize=18)
    plt.ylabel(field,fontsize=15)
    plt.xlabel('Vertical level',fontsize=15)
    plt.gca().invert_yaxis()

# %%
plot_mean_profile('pm')

# %%
plot_mean_profile('pm')

# %%
plot_mean_profile('cl_l')

# %%
plot_mean_profile('tm')

# %%
os.listdir(data_folder)
# Out:
# ['ncr_pdf_douze_05deg.nc',
#  'cl_l.nc',
#  'ncr_pdf_douze_1deg.nc',
#  'ncr_pdf_douze_0125deg.nc',
#  'ncr_pdf_douze_025deg.nc',
#  'ncr_pdf_douze_00625deg.nc']

# %% [markdown]
# ## ncr_pdf_douze_0125deg.nc, 0,125 degree correpsonds to 13,8 km

# %%
# lets look inside NetCDF input file
fname='ncr_pdf_douze_0125deg.nc'
filepath=data_folder+fname
# ds contains 63 fields
ds = xr.open_dataset(filepath)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (lev: 150, record: 15360, time: 1)
# Coordinates:
#   * time       (time) float64 2.013e+07
# Dimensions without coordinates: lev, record
# Data variables:
#     zm         (record, time, lev) float32 ...
#     qcm        (record, time, lev) float32 ...
#     qim        (record, time, lev) float32 ...
#     qvm        (record, time, lev) float32 ...
#     qtm        (record, time, lev) float32 ...
#     qlm        (record, time, lev) float32 ...
#     qvlm       (record, time, lev) float32 ...
#     qsm        (record, time, lev) float32 ...
#     qsi        (record, time, lev) float32 ...
#     tm         (record, time, lev) float32 ...
#     pm         (record, time, lev) float32 ...
#     cl         (record, time, lev) float32 ...
#     cl_l       (record, time, lev) float32 ...
#     qvu        (record, time, lev) float32 ...
#     tu         (record, time, lev) float32 ...
#     qt_min     (record, time, lev) float32 ...
#     qt_max     (record, time, lev) float32 ...
#     t_min      (record, time, lev) float32 ...
#     t_max      (record, time, lev) float32 ...
#     skew       (record, time, lev) float32 ...
#     var_l      (record, time, lev) float32 ...
#     skew_l     (record, time, lev) float32 ...
#     var        (record, time, lev) float32 ...
#     var_t      (record, time, lev) float32 ...
#     betaq_msl  (record, time, lev) float32 ...
#     betap_msl  (record, time, lev) float32 ...
#     betaa_msl  (record, time, lev) float32 ...
#     betab_msl  (record, time, lev) float32 ...
#     betaq_p00  (record, time, lev) float32 ...
#     betap_p00  (record, time, lev) float32 ...
#     betaa_p00  (record, time, lev) float32 ...
#     betab_p00  (record, time, lev) float32 ...
#     betaq_p06  (record, time, lev) float32 ...
#     betap_p06  (record, time, lev) float32 ...
#     betaa_p06  (record, time, lev) float32 ...
#     betab_p06  (record, time, lev) float32 ...
#     betaa_zsl  (record, time, lev) float32 ...
#     betab_zsl  (record, time, lev) float32 ...
#     betap_zsl  (record, time, lev) float32 ...
#     betaq_zsl  (record, time, lev) float32 ...
#     betaa_1sl  (record, time, lev) float32 ...
#     betab_1sl  (record, time, lev) float32 ...
#     betap_1sl  (record, time, lev) float32 ...
#     betaq_1sl  (record, time, lev) float32 ...
#     sat_zm     (record, time, lev) float32 ...
#     sat_z1     (record, time, lev) float32 ...
#     cl_msl     (record, time, lev) float32 ...
#     cl_p00     (record, time, lev) float32 ...
#     cl_p06     (record, time, lev) float32 ...
#     cl_zsl     (record, time, lev) float32 ...
#     cl_rel     (record, time, lev) float32 ...
#     cl_1sl     (record, time, lev) float32 ...
#     betaa_3sl  (record, time, lev) float32 ...
#     betab_3sl  (record, time, lev) float32 ...
#     betap_3sl  (record, time, lev) float32 ...
#     betaq_3sl  (record, time, lev) float32 ...
#     sat_z3     (record, time, lev) float32 ...
#     cl_3sl     (record, time, lev) float32 ...
#     betaa_p03  (record, time, lev) float32 ...
#     betab_p03  (record, time, lev) float32 ...
#     betap_p03  (record, time, lev) float32 ...
#     betaq_p03  (record, time, lev) float32 ...
#     cl_p03     (record, time, lev) float32 ...
# Attributes:
#     CDI:                       Climate Data Interface version 1.8.1 (http://m...
#     Conventions:               CF-1.6
#     history:                   Mon Mar 12 10:44:46 2018: ncrcat 2013042413-re...
#     CDO:                       Climate Data Operators version 1.8.1 (http://m...
#     NCO:                       "4.5.4"
#     nco_openmp_thread_number:  1

# %%
ds.variables
# Out:
# Frozen({'time': <xarray.IndexVariable 'time' (time: 1)>
# array([20130424.524306])
# Attributes:
#     standard_name:  time
#     units:          day as %Y%m%d.%f
#     calendar:       proleptic_gregorian
#     axis:           T, 'zm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qcm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qim': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qvm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qtm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qlm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qvlm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qsm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qsi': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'tm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'pm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl_l': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qvu': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'tu': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qt_min': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'qt_max': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 't_min': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 't_max': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'skew': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'var_l': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'skew_l': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'var': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'var_t': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaq_msl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betap_msl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaa_msl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betab_msl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32]
# Attributes:
#     time:     20130424.524305556, 'betaq_p00': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betap_p00': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaa_p00': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betab_p00': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaq_p06': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betap_p06': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaa_p06': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betab_p06': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaa_zsl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betab_zsl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betap_zsl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaq_zsl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaa_1sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betab_1sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betap_1sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaq_1sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'sat_zm': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'sat_z1': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl_msl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl_p00': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl_p06': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl_zsl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl_rel': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl_1sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaa_3sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betab_3sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betap_3sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaq_3sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'sat_z3': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl_3sl': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaa_p03': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betab_p03': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betap_p03': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'betaq_p03': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32], 'cl_p03': <xarray.Variable (record: 15360, time: 1, lev: 150)>
# [2304000 values with dtype=float32]})

# %%
# lets select pm field - mean pressure
pmvals=ds.cl_l.values
pmvals.shape
# Out:
# (15360, 1, 150)

# %%
fig=plt.figure(figsize=(9,5))
plt.grid()
plt.plot(pmvals[2][0],'-o')
plt.xlim(100,150)
# plt.ylim(0,50000)
plt.ylabel('LES liquid cloud fraction')
plt.xlabel('Height level')
plt.title('CL_l (LES liquid cloud fraction) from ncr_pdf_douze_0125deg.nc.nc, subgrid cell 1 from 15360')
plt.gca().invert_yaxis()
